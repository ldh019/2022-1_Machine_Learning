# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    diff = feature - center
    distance = np.sum(np.square(diff), axis = 1)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    n = feature.shape[0]
    m = feature.shape[1]
    
    arr = []
    centroid = np.zeros((1, m))
    
    for i in range(n):
        if label_feature[i] == label:
            arr.append(feature[i])
    
    if len(arr) != 0:
        centroid = np.mean(arr, axis = 0)
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    label_feature = np.zeros((len(distance), 1))
    
    for i in range(distance.shape[0]):
        label_feature[i, 0] = distance[i].argmin()
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %%
def compute_loss(distance, label):
    loss = 0
    n = len(label)
    
    for i in range(n):
        loss += distance[i, int(label[i])]
        
    loss /= n

    return loss

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 30     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

centroid = np.zeros((number_cluster, number_feature))
distance = np.zeros((number_data, number_cluster))

for i in range(number_iteration):
    for k in range(number_cluster):
        centroid[k] = compute_centroid(feature, label_feature_02, k)
        if centroid[k] is np.zeros((1, feature.shape[1])):
            centroid[k] = centroid[k - 1]
        distance[:,k] = compute_distance(feature, centroid[k])

    label_feature_02 = compute_label(distance)
    
    centroid_iteration_02[i] = centroid
    loss_iteration_02[i] = compute_loss(distance, label_feature_02)
    
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 30     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

centroid = np.zeros((number_cluster, number_feature))
distance = np.zeros((number_data, number_cluster))

for i in range(number_iteration):
    for k in range(number_cluster):
        centroid[k] = compute_centroid(feature, label_feature_04, k)
        if centroid[k] is np.zeros((1, feature.shape[1])):
            centroid[k] = centroid[k - 1]
        distance[:,k] = compute_distance(feature, centroid[k])

    label_feature_04 = compute_label(distance)
    
    centroid_iteration_04[i] = centroid
    loss_iteration_04[i] = compute_loss(distance, label_feature_04)

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 20     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

centroid = np.zeros((number_cluster, number_feature))
distance = np.zeros((number_data, number_cluster))

for i in range(number_iteration):
    for k in range(number_cluster):
        centroid[k] = compute_centroid(feature, label_feature_08, k)
        if centroid[k] is np.zeros((1, feature.shape[1])):
            centroid[k] = centroid[k - 1]
        distance[:,k] = compute_distance(feature, centroid[k])

    label_feature_08 = compute_label(distance)
    
    centroid_iteration_08[i] = centroid
    loss_iteration_08[i] = compute_loss(distance, label_feature_08)
    
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 50     # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

centroid = np.zeros((number_cluster, number_feature))
distance = np.zeros((number_data, number_cluster))

for i in range(number_iteration):
    for k in range(number_cluster):
        centroid[k] = compute_centroid(feature, label_feature_16, k)
        if centroid[k] is np.zeros((1, feature.shape[1])):
            centroid[k] = centroid[k - 1]
        distance[:,k] = compute_distance(feature, centroid[k])

    label_feature_16 = compute_label(distance)
    
    centroid_iteration_16[i] = centroid
    loss_iteration_16[i] = compute_loss(distance, label_feature_16)
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    plt.plot(centroid_iteration_02[0,:,0],centroid_iteration_02[0,:,1],'.',color = 'blue',label='initial')
    plt.plot(centroid_iteration_02[-1,:,0],centroid_iteration_02[-1,:,1],'.',color = 'red',label='final')
    plt.plot(centroid_iteration_02[:,0,0],centroid_iteration_02[:,0,1],'-',label=f'$cluster {0}$')


    for i in range(2):
        plt.plot(centroid_iteration_02[:,i,0],centroid_iteration_02[:,i,1],'-',label=f'$cluster {i}$')
        plt.plot(centroid_iteration_02[0,:,0],centroid_iteration_02[0,:,1],'.',color = 'blue')
        plt.plot(centroid_iteration_02[-1,:,0],centroid_iteration_02[-1,:,1],'.',color = 'red')

    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    plt.plot(centroid_iteration_04[0,:,0],centroid_iteration_04[0,:,1],'.',color = 'blue',label='initial')
    plt.plot(centroid_iteration_04[-1,:,0],centroid_iteration_04[-1,:,1],'.',color = 'red',label='final')
    plt.plot(centroid_iteration_04[:,0,0],centroid_iteration_04[:,0,1],'-',label=f'$cluster {0}$')


    for i in range(4):
        plt.plot(centroid_iteration_04[:,i,0],centroid_iteration_04[:,i,1],'-',label=f'$cluster {i}$')
        plt.plot(centroid_iteration_04[0,:,0],centroid_iteration_04[0,:,1],'.',color = 'blue')
        plt.plot(centroid_iteration_04[-1,:,0],centroid_iteration_04[-1,:,1],'.',color = 'red')

    plt.legend()
    plt.tight_layout()
    plt.show()
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    plt.plot(centroid_iteration_08[0,:,0],centroid_iteration_08[0,:,1],'.',color = 'blue',label='initial')
    plt.plot(centroid_iteration_08[-1,:,0],centroid_iteration_08[-1,:,1],'.',color = 'red',label='final')
    plt.plot(centroid_iteration_08[:,0,0],centroid_iteration_08[:,0,1],'-',label=f'$cluster {0}$')


    for i in range(8):
        plt.plot(centroid_iteration_08[:,i,0],centroid_iteration_08[:,i,1],'-',label=f'$cluster {i}$')
        plt.plot(centroid_iteration_08[0,:,0],centroid_iteration_08[0,:,1],'.',color = 'blue')
        plt.plot(centroid_iteration_08[-1,:,0],centroid_iteration_08[-1,:,1],'.',color = 'red')

    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    plt.plot(centroid_iteration_16[0,:,0],centroid_iteration_16[0,:,1],'.',color = 'blue',label='initial')
    plt.plot(centroid_iteration_16[-1,:,0],centroid_iteration_16[-1,:,1],'.',color = 'red',label='final')
    plt.plot(centroid_iteration_16[:,0,0],centroid_iteration_16[:,0,1],'-',label=f'$cluster {0}$')


    for i in range(16):
        plt.plot(centroid_iteration_16[:,i,0],centroid_iteration_16[:,i,1],'-',label=f'$cluster {i}$')
        plt.plot(centroid_iteration_16[0,:,0],centroid_iteration_16[0,:,1],'.',color = 'blue')
        plt.plot(centroid_iteration_16[-1,:,0],centroid_iteration_16[-1,:,1],'.',color = 'red')

    plt.legend()
    plt.tight_layout()
    plt.show()
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    data = np.c_[feature, label_feature_02]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 2.5, 1), cmap.N)
    plot = plt.scatter(x, y, c = label_feature_02, norm = norm, s = 30, cmap = cmap, edgecolor = 'none')

    cbar = plt.colorbar(plot, ticks = np.arange(0, 2))
    cbar.ax.set_ylabel('cluster')
    plt.tight_layout()
    plt.show()
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    data = np.c_[feature, label_feature_04]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 4.5, 1), cmap.N)
    plot = plt.scatter(x, y, c = label_feature_04, norm = norm, s = 30, cmap = cmap, edgecolor = 'none')

    cbar = plt.colorbar(plot, ticks = np.arange(0, 4))
    cbar.ax.set_ylabel('cluster')
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    data = np.c_[feature, label_feature_08]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 8.5, 1), cmap.N)
    plot = plt.scatter(x, y, c = label_feature_08, norm = norm, s = 30, cmap = cmap, edgecolor = 'none')

    cbar = plt.colorbar(plot, ticks = np.arange(0, 8))
    cbar.ax.set_ylabel('cluster')
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    data = np.c_[feature, label_feature_16]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 16.5, 1), cmap.N)
    plot = plt.scatter(x, y, c = label_feature_16, norm = norm, s = 30, cmap = cmap, edgecolor = 'none')

    cbar = plt.colorbar(plot, ticks = np.arange(0, 16))
    cbar.ax.set_ylabel('cluster')
    plt.tight_layout()
    plt.show()
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 31.1126288111
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 10.5831291650
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  6.0307066805
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  3.4523433402
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# ...
